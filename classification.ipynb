# %% [markdown]
# # MTEB Classification benchmarks
# How does the classification benchmark work?
# - each dataset contains a test and validation set
# - a KNN classifier is trained on the embeddings of the training set
#
# - the KNN classifier is used to predict the labels of the test set

# %%
import sys
sys.path.append('/Users/malte/Developer/embenchmark/packages/mteb')

from packages.mteb.mteb import MTEB
from sentence_transformers import SentenceTransformer

# %%
model_name = "average_word_embeddings_komninos"

model = SentenceTransformer(model_name)
evaluation = MTEB(tasks=["Banking77Classification"], task_langs=["en"])
results = evaluation.run(model, output_folder=f"results/{model_name}")
# Out:
# HELLO FROM LOCAL MTEB
# ───────────────────────────────────────────────── Selected tasks  ─────────────────────────────────────────────────
# Classification
#     - Banking77Classification, s2s
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# samples [[ 0.05092199  0.24896601 -0.0706625  ...  0.0455325   0.3959425
#   -0.154745  ]
#  [-0.049325    0.20964152  0.077507   ...  0.16019066  0.2823785
#   -0.18488616]
#  [-0.08887825  0.24532527 -0.1167315  ... -0.01975925  0.48691425
#   -0.17372075]
#  ...
#  [ 0.064148    0.029896   -0.236278   ...  0.14292249  0.05033
#   -0.1119195 ]
#  [ 0.012143    0.0981785  -0.11405499 ... -0.12587     0.405942
#   -0.1103135 ]
#  [ 0.113326    0.1288505  -0.01055825 ...  0.28982902  0.3634765
#   -0.15163875]]
# scores {'accuracy': 0.673051948051948, 'f1': 0.6722777735584801}
# ...

# %%
results
# Out:
# {'Banking77Classification': {'mteb_version': '1.1.1',
#   'dataset_revision': '0fd18e25b25c072e09e0d92ab615fda904d66300',
#   'mteb_dataset_name': 'Banking77Classification',
#   'test': {'accuracy': 0.6676623376623377,
#    'f1': 0.6659096432882667,
#    'accuracy_stderr': 0.005370801164091484,
#    'f1_stderr': 0.006012539207704088,
#    'main_score': 0.6676623376623377,
#    'evaluation_time': 12.34}}}
